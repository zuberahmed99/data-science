# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("PRSA_data_2010.1.1-2014.12.31.csv")
data.head()
# Out:
#    No  year  month  day  hour  pm2.5  DEWP  TEMP  PRES cbwd    Iws  Is  Ir
# 0   1  2010      1    1     0    NaN   -21   -11  1021   NW   1.79   0   0
# 1   2  2010      1    1     1    NaN   -21   -12  1020   NW   4.92   0   0
# 2   3  2010      1    1     2    NaN   -21   -11  1019   NW   6.71   0   0
# 3   4  2010      1    1     3    NaN   -21   -14  1019   NW   9.84   0   0
# 4   5  2010      1    1     4    NaN   -20   -12  1018   NW  12.97   0   0

# %%
data.dropna(axis=0,inplace=True)

# %%
data.head()
data.describe()
# Out:
#                  No          year         month           day          hour  \
# count  41757.000000  41757.000000  41757.000000  41757.000000  41757.000000
# mean   22279.380104   2012.042771      6.513758     15.685514     11.502311
# std    12658.168415      1.415311      3.454199      8.785539      6.924848
# min       25.000000   2010.000000      1.000000      1.000000      0.000000
# 25%    11464.000000   2011.000000      4.000000      8.000000      5.000000
# 50%    22435.000000   2012.000000      7.000000     16.000000     12.000000
# 75%    33262.000000   2013.000000     10.000000     23.000000     18.000000
# max    43824.000000   2014.000000     12.000000     31.000000     23.000000
#
#               pm2.5          DEWP          TEMP          PRES           Iws  \
# count  41757.000000  41757.000000  41757.000000  41757.000000  41757.000000
# mean      98.613215      1.750174     12.401561   1016.442896     23.866747
# std       92.050387     14.433658     12.175215     10.300733     49.617495
# min        0.000000    -40.000000    -19.000000    991.000000      0.450000
# 25%       29.000000    -10.000000      2.000000   1008.000000      1.790000
# 50%       72.000000      2.000000     14.000000   1016.000000      5.370000
# 75%      137.000000     15.000000     23.000000   1025.000000     21.910000
# max      994.000000     28.000000     42.000000   1046.000000    565.490000
#
#                  Is            Ir
# count  41757.000000  41757.000000
# mean       0.055344      0.194866
# std        0.778875      1.418165
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# max       27.000000     36.000000

# %%
sns.pairplot(data)

# %%
def convert_to_kelvin(temp):
    kelvin = temp + 273
    return kelvin

data['TEMP'] = data['TEMP'].apply(convert_to_kelvin)
data.head()
# Out:
#     No  year  month  day  hour  pm2.5  DEWP  TEMP  PRES cbwd   Iws  Is  Ir
# 24  25  2010      1    2     0    129   -16   269  1020   SE  1.79   0   0
# 25  26  2010      1    2     1    148   -15   269  1020   SE  2.68   0   0
# 26  27  2010      1    2     2    159   -11   268  1021   SE  3.57   0   0
# 27  28  2010      1    2     3    181    -7   268  1022   SE  5.36   1   0
# 28  29  2010      1    2     4    138    -7   268  1022   SE  6.25   2   0

# %%
df = data[['month','day','hour','pm2.5','TEMP','PRES']]

# %%
df.head()
# Out:
#     month  day  hour  pm2.5  TEMP  PRES
# 24      1    2     0    129   269  1020
# 25      1    2     1    148   269  1020
# 26      1    2     2    159   268  1021
# 27      1    2     3    181   268  1022
# 28      1    2     4    138   268  1022
